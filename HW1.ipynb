# %% [markdown]
# <a href="https://colab.research.google.com/github/Justice-Coulter/DSC-402-HW-Assignments/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/DATA/olympic_medals.csv'
data = pd.read_csv(filepath)
print(str(len(data.columns)) + " columns")
print(str(len(data.columns)) + " rows")
columns = data.columns
print(data.columns)
pd.DataFrame.dtypes
print(data.dtypes)
print("")

print("Number of unique cities: " + str(len(data['Location'].unique())) + "\n")
medal_list = data['Event']
USA_medals = 0
for entry in data.iterrows():
  #print(entry)
  if(entry[1]['Nationality'] == 'USA'):
    USA_medals += 1
print(str(USA_medals) + " medals were won by the USA")
data.groupby(by='Nationality')['Location'].count()
# Out:
# 8 columns
# 8 rows
# Index(['Gender', 'Event', 'Location', 'Year', 'Medal', 'Name', 'Nationality',
#        'Result'],
#       dtype='object')
# Gender         object
# Event          object
# Location       object
# Year            int64
# Medal          object
# Name           object
# Nationality    object
# Result         object
# dtype: object
#
# Number of unique cities: 23
#
# 638 medals were won by the USA
# Nationality
# ALG      9
# ARG      4
# AUS     57
# AUT      4
# BAH     12
#       ...
# URS    131
# USA    638
# VEN      2
# YUG      1
# ZAM      1
# Name: Location, Length: 97, dtype: int64

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/DATA/olympic_medals.csv'
data = pd.read_csv(filepath)
print(len(data.columns))
# Out:
# 8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
